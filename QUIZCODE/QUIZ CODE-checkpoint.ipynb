# %% [markdown]
# # Hamoye ID - 147dff792b01f000

# %%
#importing libraries

import numpy as np
import pandas as pd

# %%
#load the food data

food_data = pd.read_csv('foodbalancesheet_E_Africa_NOFLAG.csv', encoding='latin-1')
food_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
#Q11 find the totsl sum of animal fat produced in 2014 and 2017

food_data.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %% [markdown]
# for 2014 = 209460.54, for 2017 = 269617.53

# %%
#Q12 calculating the mean and standard deviation accross all dataset for year 2015 and to 3 decimal places

food_data['Y2015'].mean()
# Out:
# 135.23596649549236

# %% [markdown]
# mean = 135.236

# %%
food_data['Y2015'].std()
# Out:
# 1603.4039839423301

# %% [markdown]
# standard deviation = 1603.404

# %%
#Q13 getting the total number and percentage of missing data in 2016 to 2 decimal place

food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# total missing data in 2016 is  1535

# %%
#calculating the percentage of missing data in 2016 to 2 decimal place

1535/60943*100
# Out:
# 2.5187470259094566

# %% [markdown]
# percentage = 2.52

# %%
#Q14 getting the year that has the highest correllation with element code

food_data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %% [markdown]
# the answer is Y2014 with 0.024457

# %%
#Q15 getting the year with the highest sum of import quantity

food_data.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# answer is Y2017 with 294559.09

# %%
#Q16 getting the total number of sum of production in 2014

food_data.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# answer is 1931287.75

# %%
#Q17 getting the element that has the highest sum in 2018
#firstly,  print out the element and Y2018 rows

sum_element = food_data.loc[0:,['Y2018','Element']]
sum_element
# Out:
#           Y2018                                 Element
# 0      42228.00           Total Population - Both sexes
# 1          0.00                Domestic supply quantity
# 2       3322.00           Food supply (kcal/capita/day)
# 3         91.83  Protein supply quantity (g/capita/day)
# 4         77.28      Fat supply quantity (g/capita/day)
# ...         ...                                     ...
# 60938     16.00                                    Food
# 60939      1.08     Food supply quantity (kg/capita/yr)
# 60940      1.00           Food supply (kcal/capita/day)
# 60941      0.04  Protein supply quantity (g/capita/day)
# 60942      0.01      Fat supply quantity (g/capita/day)
#
# [60943 rows x 2 columns]

# %%
#perform a groupby on sum_element to get the highest sum in 2018

list = sum_element.groupby('Element').sum()
list
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# answer is Domestic supply quantity

# %%
#Q18 get the element that had the third lowest sum in Y2018

list['Y2018'].sort_values()
# Out:
# Element
# Tourist consumption                            90.00
# Fat supply quantity (g/capita/day)          10258.69
# Protein supply quantity (g/capita/day)      11833.56
# Stock Variation                             20577.91
# Seed                                        25263.14
# Residuals                                   34864.00
# Food supply quantity (kg/capita/yr)         49056.85
# Other uses (non-food)                       91300.97
# Losses                                     163902.00
# Export Quantity                            181594.80
# Feed                                       233489.68
# Import Quantity                            287997.09
# Processing                                 308429.00
# Food supply (kcal/capita/day)              455261.00
# Total Population - Both sexes             1140605.00
# Food                                      1303841.28
# Production                                2075072.89
# Domestic supply quantity                  2161192.10
# ...

# %% [markdown]
# answer is Protein supply quantity (g/capita/day)

# %%
#Q19 getting the total import quantity of algeria in 2018
#firstly, print out the dataframe required

total = food_data.groupby(['Area','Element'])['Y2018'].sum()
total
# Out:
# Area      Element
# Algeria   Domestic supply quantity                  90023.42
#           Export Quantity                             811.54
#           Fat supply quantity (g/capita/day)          309.09
#           Feed                                      10668.00
#           Food                                      63736.33
#                                                       ...
# Zimbabwe  Protein supply quantity (g/capita/day)      176.57
#           Residuals                                  -546.00
#           Seed                                        140.00
#           Stock Variation                            -447.00
#           Total Population - Both sexes             14439.00
# Name: Y2018, Length: 803, dtype: float64

# %%
#secondly, print the element for only algeria to get the import quantity sum

total.loc['Algeria']
# Out:
# Element
# Domestic supply quantity                  90023.42
# Export Quantity                             811.54
# Fat supply quantity (g/capita/day)          309.09
# Feed                                      10668.00
# Food                                      63736.33
# Food supply (kcal/capita/day)             13288.00
# Food supply quantity (kg/capita/yr)        1509.28
# Import Quantity                           36238.29
# Losses                                     7708.00
# Other uses (non-food)                      3970.08
# Processing                                 2479.00
# Production                                60766.67
# Protein supply quantity (g/capita/day)      367.28
# Residuals                                   630.00
# Seed                                        825.00
# Stock Variation                            6172.00
# Total Population - Both sexes             42228.00
# Name: Y2018, dtype: float64

# %% [markdown]
# answer is 36238.29

# %%
#Q20 get the total number of unique countries in the food data

food_data.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %% [markdown]
# countries is the area which is 49
